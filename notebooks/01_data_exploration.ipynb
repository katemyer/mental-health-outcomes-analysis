# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/murder_data.csv")
print(df.shape)
# Out:
# (913067, 30)

# %%
print(df.columns.tolist())
# Out:
# ['ID', 'CNTYFIPS', 'Ori', 'State', 'Agency', 'Agentype', 'Source', 'Solved', 'Year', 'Month', 'Incident', 'ActionType', 'Homicide', 'Situation', 'VicAge', 'VicSex', 'VicRace', 'VicEthnic', 'OffAge', 'OffSex', 'OffRace', 'OffEthnic', 'Weapon', 'Relationship', 'Circumstance', 'Subcircum', 'VicCount', 'OffCount', 'FileDate', 'MSA']

# %%
print(df.dtypes)
# Out:
# ID                  str
# CNTYFIPS            str
# Ori                 str
# State               str
# Agency              str
# Agentype            str
# Source              str
# Solved              str
# Year              int64
# Month               str
# Incident          int64
# ActionType          str
# Homicide            str
# Situation           str
# VicAge            int64
# VicSex              str
# VicRace             str
# VicEthnic           str
# OffAge            int64
# OffSex              str
# OffRace             str
# OffEthnic           str
# Weapon              str
# Relationship        str
# Circumstance        str
# Subcircum           str
# VicCount          int64
# OffCount          int64
# FileDate        float64
# MSA                 str
# dtype: object

# %%
print(df.head())
# Out:
#                  ID       CNTYFIPS      Ori   State     Agency  \
# 0  197603001AK00101  Anchorage, AK  AK00101  Alaska  Anchorage
# 1  197604001AK00101  Anchorage, AK  AK00101  Alaska  Anchorage
# 2  197606001AK00101  Anchorage, AK  AK00101  Alaska  Anchorage
# 3  197606002AK00101  Anchorage, AK  AK00101  Alaska  Anchorage
# 4  197607001AK00101  Anchorage, AK  AK00101  Alaska  Anchorage
#
#            Agentype Source Solved  Year  Month  ...  \
# 0  Municipal police    FBI    Yes  1976  March  ...
# 1  Municipal police    FBI    Yes  1976  April  ...
# 2  Municipal police    FBI    Yes  1976   June  ...
# 3  Municipal police    FBI    Yes  1976   June  ...
# 4  Municipal police    FBI    Yes  1976   July  ...
#
#                              OffRace                OffEthnic  \
# 0                              Black  Unknown or not reported
# 1                              White  Unknown or not reported
# 2                              Black  Unknown or not reported
# ...
